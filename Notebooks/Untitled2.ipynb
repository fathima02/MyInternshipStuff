# %%
'''#ratings1_df.describe()
# Printing the ratings dataset

ratings1_df.rename(columns={'User': 'BrukerID'}, inplace=True)
ratings1_df.rename(columns={'vmID': 'FilmID'}, inplace=True)
ratings1_df.rename(columns={'ratings': 'Rangering'}, inplace=True)
ratings1_df.head()
num_rows = 30000
reduced_df = ratings_df[:num_rows]
reduced_df['BrukerID'] = range(1, len(reduced_df) + 1)
reduced_df.head()
columns_to_keep = ['BrukerID','Tidstempel']
reduced_df= reduced_df[columns_to_keep]
ratings1_df = ratings1_df.merge(reduced_df, on='BrukerID')
ratings1_df.head()'''

# absolutely worthless commands DO NOT USE

# %%
<br><br>
### <a id="content-based"></a>2.3) Content Based Filtering
[*Back to top*](#top)

For the content-based filtering (CBF) models, I use the information about the users' movie preferences to predict recommendations. In particular, the CBF models use information about what each user has rated, what they rated, and the rated movie's genres to build an individual model for each user. The model then predicts ratings for all of the other movies in the dataset the user has not seen. 

I want to test a variety of different machine learning algorithms to establish which one is most beneficial for content-based recommendations on this dataset. Even though I suspect that the linear models will perform best, I will try out a few other types of machine learning algorithms as well for my own learning purposes.

The main advantage of CBF is that it takes individual user preferences into consideration. For movie recommendations, this is quite fitting, as we often have a few favourite movie genres, actors, directors, etc. that we enjoy more than others. Sadly, the movies dataset from MovieLens contains very few movie features, and content-based filtering models usually need a multitude of item features in order to accurately model user preferences. I will attempt to alleviate these problems with featue engineering in section 3. 

Another disadvantage with CBF is that these models struggle with very sparse matrices. I will likely encounter this exact issue, as most users only rate a few movies. In contrast to collaborative filtering, CBF models also have a disadvantage in that they don't consider similarities between users, since they only focus on items (content) and individual users. 

My hypothesis is that a content-based model which only uses the movie genre and user data will not be able to outperform the baseline model. To achieve this, CBF requires more features in the movies dataset. It will however be interesting to see how close I can get, and which model will perform best. The most successful model will be used in the hybrid recommender in chapter 2.5. 
<br>
<br>

# %%
<br><br>
### <a id="baseline"></a>2.2) The Baseline Model
In order to provide context for the evaluation of more advanced recommendation models, I will begin with constructing a very simple baseline model. I will use a popularity-based approach, where I calculate the average rating for each movie and simply predict that all users rate all movies after the movies' average rating. Even though this model provides no personalization, most users to in fact rate movies close to the average rating for the movies. I therefore expect that the RMSE for this model will prove to be somewhat challenging to beat.
<br><br>

# %%
records_per_policy=1007
cols=['User','vmID','Read_Iops','Write_Iops','Read_Latency','Write_Latency','CPU_Cores','Policy_Num','Cloud_%','Reliability_%','Cost_$']

# Generating Data for Policy 1
list_data=[]
for i in range(records_per_policy):
    new_list=[]
    # User
    new_list.append(randint(1,300))
    # VmID
    new_list.append(randint(1,10))
    # Read Iops
    new_list.append(randint(1,50))
    # Write Iops
    new_list.append(randint(1,50))
    # Read Latency
    new_list.append(randint(200,300))
    # Write Latency
    new_list.append(randint(200,300))
    # CPU Cores
    new_list.append(randint(1,15))
    # Policy Number
    new_list.append(1)
    #Cloud
    new_list.append(randint(20,98))
    #Reliability
    new_list.append(randint(20,98))
    #Cost 
    new_list.append(randint(10000,20000))
    list_data.append(new_list)
    
df_1=pd.DataFrame(list_data,columns=cols)

# Generating Data for Policy 2
list_data=[]
for i in range(records_per_policy):
    new_list=[]
    # User
    new_list.append(randint(1,300))
    # VmID
    new_list.append(randint(11,20))
    # Read Iops
    new_list.append(randint(25,75))
    # Write Iops
    new_list.append(randint(25,75))
    # Read Latency
    new_list.append(randint(150,250))
    # Write Latency
    new_list.append(randint(150,250))
    # CPU Cores
    new_list.append(randint(10,25))
    # Policy Number
    new_list.append(2)
    #Cloud
    new_list.append(randint(20,98))
    #Reliability
    new_list.append(randint(20,98))
    #Cost 
    new_list.append(randint(10000,20000))
    list_data.append(new_list)
    
df_2=pd.DataFrame(list_data,columns=cols)

# Generating Data for Policy 3
list_data=[]
for i in range(records_per_policy):
    new_list=[]
    # User
    new_list.append(randint(1,300))
    # VmID
    new_list.append(randint(21,30))
    # Read Iops
    new_list.append(randint(25,100))
    # Write Iops
    new_list.append(randint(25,100))
    # Read Latency
    new_list.append(randint(100,225))
    # Write Latency
    new_list.append(randint(100,225))
    # CPU Cores
    new_list.append(randint(20,35))
    # Policy Number
    new_list.append(3)
    #Cloud
    new_list.append(randint(20,98))
    #Reliability
    new_list.append(randint(20,98))
    #Cost 
    new_list.append(randint(10000,20000))
    list_data.append(new_list)
    
df_3=pd.DataFrame(list_data,columns=cols)

# Generating Data for Policy 4
list_data=[]
for i in range(records_per_policy):
    new_list=[]
    # User
    new_list.append(randint(1,300))
    # VmID
    new_list.append(randint(31,40))
    # Read Iops
    new_list.append(randint(50,125))
    # Write Iops
    new_list.append(randint(50,125))
    # Read Latency
    new_list.append(randint(75,175))
    # Write Latency
    new_list.append(randint(75,175))
    # CPU Cores
    new_list.append(randint(30,45))
    # Policy Number
    new_list.append(4)
    #Cloud
    new_list.append(randint(20,98))
    #Reliability
    new_list.append(randint(20,98))
    #Cost 
    new_list.append(randint(10000,20000))
    list_data.append(new_list)
    
df_4=pd.DataFrame(list_data,columns=cols)

# Generating Data for Policy 5
list_data=[]
for i in range(records_per_policy):
    new_list=[]
    # User
    new_list.append(randint(1,300))
    # VmID
    new_list.append(randint(41,50))
    # Read Iops
    new_list.append(randint(75,150))
    # Write Iops
    new_list.append(randint(75,150))
    # Read Latency
    new_list.append(randint(25,125))
    # Write Latency
    new_list.append(randint(25,125))
    # CPU Cores
    new_list.append(randint(40,55))
    # Policy Number
    new_list.append(5)
    #Cloud
    new_list.append(randint(20,98))
    #Reliability
    new_list.append(randint(20,98))
    #Cost 
    new_list.append(randint(10000,20000))
    list_data.append(new_list)
    
df_5=pd.DataFrame(list_data,columns=cols)

# Generating Data for Policy 6
list_data=[]
for i in range(records_per_policy):
    new_list=[]
    # User
    new_list.append(randint(1,300))
    # VmID
    new_list.append(randint(51,60))
    # Read Iops
    new_list.append(randint(100,175))
    # Write Iops
    new_list.append(randint(100,175))
    # Read Latency
    new_list.append(randint(1,75))
    # Write Latency
    new_list.append(randint(1,75))
    # CPU Cores
    new_list.append(randint(50,65))
    # Policy Number
    new_list.append(6)
    #Cloud
    new_list.append(randint(20,98))
    #Reliability
    new_list.append(randint(20,98))
    #Cost 
    new_list.append(randint(10000,20000))
    list_data.append(new_list)
    
df_6=pd.DataFrame(list_data,columns=cols)

# Merging Datasets

merged_df=pd.concat([df_1,df_2,df_3,df_4,df_5,df_6],ignore_index=True)
merged_df

final_df=merged_df.sample(frac=1,ignore_index=True,random_state=42)
final_df
# Out:
#       User  vmID  Read_Iops  Write_Iops  Read_Latency  Write_Latency  \
# 0      214    37        117         123            81             91
# 1      283    16         59          68           192            211
# 2       69    41        122          99            85            100
# 3       72    38         97          82           148            165
# 4       98    31         65          62           112            106
# ...    ...   ...        ...         ...           ...            ...
# 6037   116    36        108          67           113            127
# 6038   154    51        125         131            29             56
# 6039    21    52        109         107            61             23
# 6040    45    59        122         133            11             46
# 6041   164    10         14          30           271            287
#
#       CPU_Cores  Policy_Num  Cloud_%  Reliability_%  Cost_$
# 0            40           4       36             22   15831
# 1            22           2       75             40   14050
# 2            40           5       86             86   16818
# 3            36           4       20             58   19129
# 4            43           4       55             49   13838
# ...         ...         ...      ...            ...     ...
# 6037         44           4       70             32   11848
# 6038         56           6       79             31   19503
# 6039         56           6       95             47   13838
# 6040         59           6       36             47   10923
# 6041          9           1       33             95   11655
#
# [6042 rows x 11 columns]

# %%
final_df['User'].nunique()
# Out:
# 300

# %%
from random import randint
import pandas as pd
import numpy as np
